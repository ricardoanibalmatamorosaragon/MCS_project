# %%
#errore relativo windows python matlab
import numpy as np
import plotly.plotly as py
import plotly
import matplotlib.pyplot as plt

x = np.arange(10)

fig = plt.figure()
ax = plt.subplot(111)
y_data_python_w=[6.3730e-07,2.4936e-14,2.4191e-16,3.7973e-13,1.2186e-12,2.6439e-11,2.6728e-10,7.8414e-11,2.7419e-12]
x_rows=[6867,70656,81920,123440,525825,715176,1465137,1564794,1585478]
y_data_matlab_w=[6.8030e-07,9.4510e-14,2.3769e-16,4.1298e-13,1.0859e-12,4.3741e-11,1.0591e-10,1.015e-12,3.5231e-12]


ax.plot(x_rows,y_data_python_w, label ='python')
ax.plot(x_rows,y_data_matlab_w, label ='matlab')



# Shrink current axis by 20%
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 3, box.height* 3])

# Put a legend to the right of the current axis
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.title('confronto errore windows')
plt.ylabel('errore relativo')
plt.xlabel('righe')
plt.grid()

plt.yscale('log')
plt.xscale('log')

plt.show()

# %%
#errore relativo windows
x = np.arange(10)

fig = plt.figure()
ax = plt.subplot(111)
y_data_python_w=[6.3730e-07,2.4936e-14,2.4191e-16,3.7973e-13,1.2186e-12,2.6439e-11,2.7419e-12]
x_rows=[6867,70656,81920,123440,525825,715176,1585478]
y_data_matlab_w=[6.8030e-07,9.4510e-14,2.3769e-16,4.1298e-13,1.0859e-12,4.3741e-11,3.5231e-12]
y_data_eigen_w=[7.2664e-07,2.5655e-12,2.4293e-16,5.5853e-12,2.4557e-12,9.8846e-11,6.2847e-12]

ax.plot(x_rows,y_data_python_w, label ='python')
ax.plot(x_rows,y_data_matlab_w, label ='matlab')
ax.plot(x_rows,y_data_eigen_w, label ='eigen')


# Shrink current axis by 20%
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 3, box.height* 3])

# Put a legend to the right of the current axis
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.title('confronto errore windows')
plt.ylabel('errore relativo')
plt.xlabel('righe')
plt.grid()

plt.yscale('log')
plt.xscale('log')

plt.show()

# %%
#grafico errore relativo linux
x = np.arange(10)

fig = plt.figure()
ax = plt.subplot(111)
y_data_python_l=[6.2548e-07,6.4155e-14,2.0155e-16,2.6561e-13,6.8162e-13,3.5977e-11,3.8833e-12]
x_rows=[6867,70656,81920,123440,525825,715176,1585478]
y_data_matlab_l=[6.8030e-07,9.4510e-14,2.3769e-16,4.1298e-13,1.0859e-12,4.3741e-11,3.5231e-12]
y_data_eigen_l=[7.2664e-07,2.5655e-12,2.4293e-16,5.5853e-12,2.4557e-12,9.8846e-11,6.2847e-12]

ax.plot(x_rows,y_data_python_l, label ='python')
ax.plot(x_rows,y_data_matlab_l, label ='matlab')
ax.plot(x_rows,y_data_eigen_l, label ='eigen')


# Shrink current axis by 20%
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 3, box.height* 3])

# Put a legend to the right of the current axis
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.title('confronto errore linux-mint')
plt.ylabel('errore relativo')
plt.xlabel('righe')
plt.grid()

plt.yscale('log')
plt.xscale('log')

plt.show()

# %%
#grafico per la memoria linux
x = np.arange(10)

fig = plt.figure()
ax = plt.subplot(111)
y_data_python_l=[64.21,144.39,76.24,208.88,313.29,313.58,291.58]
x_rows=[6867,70656,81920,123440,525825,715176,1585478]
y_data_matlab_l=[40.30,98.36,46.70,897.47,190.37,1580,2616.26]
y_data_eigen_l=[5.12,439.50,36.02,888.20,493.60,2590,2092]

ax.plot(x_rows,y_data_python_l, label ='python')
ax.plot(x_rows,y_data_matlab_l, label ='matlab')
ax.plot(x_rows,y_data_eigen_l, label ='eigen')


# Shrink current axis by 20%
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 3, box.height* 3])

# Put a legend to the right of the current axis
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.title('confronto memoria linux-mint')
plt.ylabel('Memoria (MB)')
plt.xlabel('righe')
plt.grid()

plt.yscale('log')
plt.xscale('log')

plt.show()

# %%
#grafico per la memoria windows
x = np.arange(10)

fig = plt.figure()
ax = plt.subplot(111)
y_data_python_w=[48.52,112.05,56.29,174.92,310.08,290.75,427.464]
x_rows=[6867,70656,81920,123440,525825,715176,1585478]
y_data_matlab_w=[31.60,114.90,62.70,745.80,588,1966.90,2403.8]
y_data_eigen_w=[2.80,441.3,36.7,890.8,496,2600,2100]

ax.plot(x_rows,y_data_python_w, label ='python')
ax.plot(x_rows,y_data_matlab_w, label ='matlab')
ax.plot(x_rows,y_data_eigen_w, label ='eigen')


# Shrink current axis by 20%
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 3, box.height* 3])

# Put a legend to the right of the current axis
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.title('confronto memoria windows10')
plt.ylabel('Memoria (MB)')
plt.xlabel('righe')
plt.grid()

plt.yscale('log')
plt.xscale('log')

plt.show()

# %%
#memoria windows python matlab
import numpy as np
import plotly.plotly as py
import plotly
import matplotlib.pyplot as plt

x = np.arange(10)

fig = plt.figure()
ax = plt.subplot(111)
y_data_python_w=[48.52,112.05,56.29,174.92,310.08,290.75,15300,20100,427.464]
x_rows=[6867,70656,81920,123440,525825,715176,1465137,1564794,1585478]
y_data_matlab_w=[31.60,114.90,62.70,745.80,588,1966.90,11622.51,21188.92,2403.8]


ax.plot(x_rows,y_data_python_w, label ='python')
ax.plot(x_rows,y_data_matlab_w, label ='matlab')



# Shrink current axis by 20%
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 3, box.height* 3])

# Put a legend to the right of the current axis
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.title('confronto memoria windows10')
plt.ylabel('memoria (MB)')
plt.xlabel('righe')
plt.grid()

plt.yscale('log')
plt.xscale('log')

plt.show()

# %%
#tempo computazionale windows python matlab
import numpy as np
import plotly.plotly as py
import plotly
import matplotlib.pyplot as plt

x = np.arange(10)

fig = plt.figure()
ax = plt.subplot(111)
y_data_python_w=[0.2889,13.8502,2.9798,30.1058,24.4661,143.9020,2171.5908,2166.1408,85.6374]
x_rows=[6867,70656,81920,123440,525825,715176,1465137,1564794,1585478]
y_data_matlab_w=[0.0245,1.3277,0.3021,2.7846,2.16713,7.2143,1150.2996,1952.1743,10.1784]


ax.plot(x_rows,y_data_python_w, label ='python')
ax.plot(x_rows,y_data_matlab_w, label ='matlab')



# Shrink current axis by 20%
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 3, box.height* 3])

# Put a legend to the right of the current axis
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.title('confronto tempo computazionale windows10')
plt.ylabel('tempo (s)')
plt.xlabel('righe')
plt.grid()

plt.yscale('log')
plt.xscale('log')

plt.show()

# %%
#grafico tempo computazionale windows
x = np.arange(10)

fig = plt.figure()
ax = plt.subplot(111)
y_data_python_w=[0.2889,13.8502,2.9798,30.1058,24.4661,143.9020,85.6374]
x_rows=[6867,70656,81920,123440,525825,715176,1585478]
y_data_matlab_w=[0.0245,1.3277,0.3021,2.7846,2.16713,7.2143,10.1784]

y_data_eigen_w=[6.2770,239.4570,27.3860,633.4610,72.8920,915.049,363.1080]

ax.plot(x_rows,y_data_python_w, label ='python')
ax.plot(x_rows,y_data_matlab_w, label ='matlab')
ax.plot(x_rows,y_data_eigen_w, label ='eigen')


# Shrink current axis by 20%
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 3, box.height* 3])

# Put a legend to the right of the current axis
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.title('confronto tempo computazionale windows10')
plt.ylabel('Tempo (s)')
plt.xlabel('righe')
plt.grid()

plt.yscale('log')
plt.xscale('log')

plt.show()

# %%
#grafico per tempo computazionale linux
x = np.arange(10)

fig = plt.figure()
ax = plt.subplot(111)
y_data_python_l=[1.1164,5.3412,2.2536,9.4515,14.7158,48.1994,46.9964]
x_rows=[6867,70656,81920,123440,525825,715176,1585478]
y_data_matlab_l=[0.2437,1.0281,0.1646,2.2566,1.8600,6.3800,8.2881]
y_data_eigen_l=[0.2983,140.4613,3.9617,446.2157,85.4052,1727.1346,920.6199]

ax.plot(x_rows,y_data_python_l, label ='python')
ax.plot(x_rows,y_data_matlab_l, label ='matlab')
ax.plot(x_rows,y_data_eigen_l, label ='eigen')


# Shrink current axis by 20%
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 3, box.height* 3])

# Put a legend to the right of the current axis
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.title('confronto tempo computazionale linux-mint')
plt.ylabel('Tempo (s)')
plt.xlabel('righe')
plt.grid()

plt.yscale('log')
plt.xscale('log')

plt.show()

# %%
#grafico per tempo computazionale linux vs windows
x = np.arange(10)

fig = plt.figure()
ax = plt.subplot(111)
y_data_python_w=[0.2889,13.8502,2.9798,30.1058,24.4661,143.9020,85.6374]
x_rows=[6867,70656,81920,123440,525825,715176,1585478]
y_data_matlab_w=[0.0245,1.3277,0.3021,2.7846,2.16713,7.2143,10.1784]

y_data_eigen_w=[6.2770,239.4570,27.3860,633.4610,72.8920,915.049,363.1080]

ax.plot(x_rows,y_data_python_w, label ='python_w')
ax.plot(x_rows,y_data_matlab_w, label ='matlab_w')
ax.plot(x_rows,y_data_eigen_w, label ='eigen_w')

y_data_python_l=[1.1164,5.3412,2.2536,9.4515,14.7158,48.1994,46.9964]

y_data_matlab_l=[0.2437,1.0281,0.1646,2.2566,1.8600,6.3800,8.2881]
y_data_eigen_l=[0.2983,140.4613,3.9617,446.2157,85.4052,1727.1346,920.6199]

ax.plot(x_rows,y_data_python_l, label ='python_l')
ax.plot(x_rows,y_data_matlab_l, label ='matlab_l')
ax.plot(x_rows,y_data_eigen_l, label ='eigen_l')


# Shrink current axis by 20%
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 3, box.height* 3])

# Put a legend to the right of the current axis
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.title('confronto tempo computazionale linux-mint vs windows 10')
plt.ylabel('Tempo (s)')
plt.xlabel('righe')
plt.grid()

plt.yscale('log')
plt.xscale('log')

plt.show()

# %%
#grafico per la memoria windows
x = np.arange(10)

fig = plt.figure()
ax = plt.subplot(111)
y_data_python_w=[48.52,112.05,56.29,174.92,310.08,290.75,427.464]
x_rows=[6867,70656,81920,123440,525825,715176,1585478]
y_data_matlab_w=[31.60,114.90,62.70,745.80,588,1966.90,2403.8]
y_data_eigen_w=[2.80,441.3,36.7,890.8,496,2600,2100]
y_data_python_l=[64.21,144.39,76.24,208.88,313.29,313.58,291.58]
y_data_matlab_l=[40.30,98.36,46.70,897.47,190.37,1580,2616.26]
y_data_eigen_l=[5.12,439.50,36.02,888.20,493.60,2590,2092]

ax.plot(x_rows,y_data_python_l, label ='python_l')
ax.plot(x_rows,y_data_matlab_l, label ='matlab_l')
ax.plot(x_rows,y_data_eigen_l, label ='eigen_l')

ax.plot(x_rows,y_data_python_w, label ='python_w')
ax.plot(x_rows,y_data_matlab_w, label ='matlab_w')
ax.plot(x_rows,y_data_eigen_w, label ='eigen_w')


# Shrink current axis by 20%
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 3, box.height* 3])

# Put a legend to the right of the current axis
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.title('confronto memoria linux-mint vs windows10')
plt.ylabel('Memoria (MB)')
plt.xlabel('righe')
plt.grid()

plt.yscale('log')
plt.xscale('log')

plt.show()

# %%
#grafico errore relativo linux
x = np.arange(10)

fig = plt.figure()
ax = plt.subplot(111)
y_data_python_l=[6.2548e-07,6.4155e-14,2.0155e-16,2.6561e-13,6.8162e-13,3.5977e-11,3.8833e-12]
x_rows=[6867,70656,81920,123440,525825,715176,1585478]
y_data_matlab_l=[6.8030e-07,9.4510e-14,2.3769e-16,4.1298e-13,1.0859e-12,4.3741e-11,3.5231e-12]
y_data_eigen_l=[7.2664e-07,2.5655e-12,2.4293e-16,5.5853e-12,2.4557e-12,9.8846e-11,6.2847e-12]
y_data_python_w=[6.3730e-07,2.4936e-14,2.4191e-16,3.7973e-13,1.2186e-12,2.6439e-11,2.7419e-12]
y_data_matlab_w=[6.8030e-07,9.4510e-14,2.3769e-16,4.1298e-13,1.0859e-12,4.3741e-11,3.5231e-12]
y_data_eigen_w=[7.2664e-07,2.5655e-12,2.4293e-16,5.5853e-12,2.4557e-12,9.8846e-11,6.2847e-12]

ax.plot(x_rows,y_data_python_w, label ='python_w')
ax.plot(x_rows,y_data_matlab_w, label ='matlab_w')
ax.plot(x_rows,y_data_eigen_w, label ='eigen_w')

ax.plot(x_rows,y_data_python_l, label ='python_l')
ax.plot(x_rows,y_data_matlab_l, label ='matlab_l')
ax.plot(x_rows,y_data_eigen_l, label ='eigen_l')


# Shrink current axis by 20%
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 3, box.height* 3])

# Put a legend to the right of the current axis
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.title('confronto errore linux-mint')
plt.ylabel('errore relativo')
plt.xlabel('righe')
plt.grid()

plt.yscale('log')
plt.xscale('log')

plt.show()
